# %%
import pandas as pd

# %%
pd.DataFrame({'Yes':[10,20], 'No':[12,13]})
# Out:
#    Yes  No
# 0   10  12
# 1   20  13

# %%
pd.DataFrame({'Bob': ['I liked it.', 'It was awful.'], 'Sue': ['Pretty good.', 'Bland.']})
# Out:
#              Bob           Sue
# 0    I liked it.  Pretty good.
# 1  It was awful.        Bland.

# %%
pd.DataFrame({'Bob': ['I liked it.', 'It was awful.','This is bad'], 
              'Sue': ['Pretty good.', 'Bland.','Test']},
             index=['Product A', 'Product B','C'])
# Out:
#                      Bob           Sue
# Product A    I liked it.  Pretty good.
# Product B  It was awful.        Bland.
# C            This is bad          Test

# %%
wine_reviews = pd.read_csv('winemag-data-130k-v2.csv', index_col=0)

# %%
wine_reviews.shape
# Out:
# (129971, 13)

# %%
wine_reviews.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# ...

# %%
wine_reviews
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price  \
# 0                                 Vulkà Bianco      87    NaN
# ...

# %%
wine_reviews.country
# Out:
# 0            Italy
# 1         Portugal
# 2               US
# 3               US
# 4               US
#             ...
# 129966     Germany
# 129967          US
# 129968      France
# 129969      France
# 129970      France
# Name: country, Length: 129971, dtype: object

# %%
wine_reviews['country']
# Out:
# 0            Italy
# 1         Portugal
# 2               US
# 3               US
# 4               US
#             ...
# 129966     Germany
# 129967          US
# 129968      France
# 129969      France
# 129970      France
# Name: country, Length: 129971, dtype: object

# %%
wine_reviews['country'][0]
# Out:
# 'Italy'

# %%
wine_reviews.iloc[0]
# Out:
# country                                                              Italy
# description              Aromas include tropical fruit, broom, brimston...
# designation                                                   Vulkà Bianco
# points                                                                  87
# price                                                                  NaN
# province                                                 Sicily & Sardinia
# region_1                                                              Etna
# region_2                                                               NaN
# taster_name                                                  Kerin O’Keefe
# taster_twitter_handle                                         @kerinokeefe
# title                                    Nicosia 2013 Vulkà Bianco  (Etna)
# variety                                                        White Blend
# ...

# %%
wine_reviews.iloc[-2:,0]
# Out:
# 129969    France
# 129970    France
# Name: country, dtype: object

# %%
wine_reviews.loc[2:9,['country','title','price']]
# Out:
#    country                                              title  price
# 2       US      Rainstorm 2013 Pinot Gris (Willamette Valley)   14.0
# 3       US  St. Julian 2013 Reserve Late Harvest Riesling ...   13.0
# 4       US  Sweet Cheeks 2012 Vintner's Reserve Wild Child...   65.0
# 5    Spain  Tandem 2011 Ars In Vitro Tempranillo-Merlot (N...   15.0
# 6    Italy   Terre di Giurfo 2013 Belsito Frappato (Vittoria)   16.0
# 7   France              Trimbach 2012 Gewurztraminer (Alsace)   24.0
# 8  Germany  Heinz Eifel 2013 Shine Gewürztraminer (Rheinhe...   12.0
# 9   France  Jean-Baptiste Adam 2012 Les Natures Pinot Gris...   27.0

# %%
wine_reviews.set_index('title')
# Out:
#                                                      country  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                      Italy
# Quinta dos Avidagos 2011 Avidagos Red (Douro)       Portugal
# Rainstorm 2013 Pinot Gris (Willamette Valley)             US
# St. Julian 2013 Reserve Late Harvest Riesling (...        US
# Sweet Cheeks 2012 Vintner's Reserve Wild Child ...        US
# ...                                                      ...
# Dr. H. Thanisch (Erben Müller-Burggraef) 2013 B...   Germany
# Citation 2004 Pinot Noir (Oregon)                         US
# Domaine Gresser 2013 Kritt Gewurztraminer (Alsace)    France
# Domaine Marcel Deiss 2012 Pinot Gris (Alsace)         France
# Domaine Schoffit 2012 Lieu-dit Harth Cuvée Caro...    France
#
#                                                                                           description  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                   Aromas include tropical fruit, broom, brimston...
# ...

# %%
wine_reviews.country == 'US'
# Out:
# 0         False
# 1         False
# 2          True
# 3          True
# 4          True
#           ...
# 129966    False
# 129967     True
# 129968    False
# 129969    False
# 129970    False
# Name: country, Length: 129971, dtype: bool

# %%
wine_reviews.loc[wine_reviews.country == 'US']
# Out:
#        country                                        description  \
# 2           US  Tart and snappy, the flavors of lime flesh and...
# 3           US  Pineapple rind, lemon pith and orange blossom ...
# 4           US  Much like the regular bottling from 2012, this...
# 10          US  Soft, supple plum envelopes an oaky structure ...
# 12          US  Slightly reduced, this wine offers a chalky, t...
# ...        ...                                                ...
# 129945      US  Hailing from one of the more popular vineyards...
# 129949      US  There's no bones about the use of oak in this ...
# 129950      US  This opens with herbaceous dollops of thyme an...
# 129952      US  This Zinfandel from the eastern section of Nap...
# 129967      US  Citation is given as much as a decade of bottl...
#
#                                designation  points  price    province  \
# 2                                      NaN      87   14.0      Oregon
# ...

# %%
reviews = wine_reviews

# %%
reviews
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price  \
# 0                                 Vulkà Bianco      87    NaN
# ...

# %%
reviews[(reviews.country == 'US') | (reviews.points >= 90)]
# Out:
#         country                                        description  \
# 2            US  Tart and snappy, the flavors of lime flesh and...
# 3            US  Pineapple rind, lemon pith and orange blossom ...
# 4            US  Much like the regular bottling from 2012, this...
# 10           US  Soft, supple plum envelopes an oaky structure ...
# 12           US  Slightly reduced, this wine offers a chalky, t...
# ...         ...                                                ...
# 129966  Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967       US  Citation is given as much as a decade of bottl...
# 129968   France  Well-drained gravel soil gives this wine its c...
# 129969   France  A dry style of Pinot Gris, this is crisp with ...
# 129970   France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price    province  \
# 2                                          NaN      87   14.0      Oregon
# ...

# %%
reviews.loc[reviews.country.isin(['US','France'])]
# Out:
#        country                                        description  \
# 2           US  Tart and snappy, the flavors of lime flesh and...
# 3           US  Pineapple rind, lemon pith and orange blossom ...
# 4           US  Much like the regular bottling from 2012, this...
# 7       France  This dry and restrained wine offers spice in p...
# 9       France  This has great depth of flavor with its fresh ...
# ...        ...                                                ...
# 129965  France  While it's rich, this beautiful dry wine also ...
# 129967      US  Citation is given as much as a decade of bottl...
# 129968  France  Well-drained gravel soil gives this wine its c...
# 129969  France  A dry style of Pinot Gris, this is crisp with ...
# 129970  France  Big, rich and off-dry, this is powered by inte...
#
#                                designation  points  price  province  \
# 2                                      NaN      87   14.0    Oregon
# ...

# %%
reviews.loc[reviews.price.notnull()]
# Out:
#          country                                        description  \
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# 5          Spain  Blackberry and raspberry aromas show a typical...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price        province  \
# ...
